# %% [markdown]
# ## PRUEBAS PARA EL STAR RATIG RECOMMENDATOR

# %% [markdown]
# IMPORTS

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import numpy as np
import os
import ipdb

# %% [markdown]
# CLASES

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

class MovieRecommenderBase:
    def __init__(self, data_path='../src/data/movie.csv'):
        """
        Base class for movie recommenders
        """
        self.movies = pd.read_csv(data_path)
        self.tfidf_matrix, self.sim_matrix = self._build_similarity_matrix()
    
    def _build_similarity_matrix(self):
        """Build similarity matrices"""
        tfidf_vector = TfidfVectorizer(stop_words='english')
        tfidf_matrix = tfidf_vector.fit_transform(self.movies['genres'])
        sim_matrix = linear_kernel(tfidf_matrix, tfidf_matrix)
        return tfidf_matrix, sim_matrix
    
    def _process_user_preferences(self, user_preferences):
        """
        Process user preferences (to be overridden by child classes)
        """
        raise NotImplementedError("This method should be implemented by child classes")

# %%
recomm = MovieRecommenderBase(data_path='../src/data/movie.csv')

# %%
print(recomm.tfidf_matrix)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 56725 stored elements and shape (27278, 23)>
#   Coords	Values
#   (0, 1)	0.41915098224772934
#   (0, 2)	0.5182685890892543
#   (0, 3)	0.5057418311427628
#   (0, 4)	0.26417526349980835
#   (0, 8)	0.47973612958726514
#   (1, 1)	0.5153114036141762
#   (1, 3)	0.6217676777828729
#   (1, 8)	0.5897958224417
#   (2, 4)	0.6025827181224164
#   (2, 18)	0.7980564314759957
#   (3, 4)	0.5445407956731659
#   (3, 18)	0.7211861062695482
#   (3, 7)	0.4282124729283388
#   (4, 4)	1.0
#   (5, 0)	0.5761440202585545
#   (5, 5)	0.610238706312681
#   (5, 20)	0.5437525073396314
#   (6, 4)	0.6025827181224164
#   (6, 18)	0.7980564314759957
#   (7, 1)	0.6381151242011527
#   (7, 3)	0.7699409641431916
#   (8, 0)	1.0
#   (9, 1)	0.6367442942511372
#   (9, 0)	0.5607679884473361
#   (9, 20)	0.5292409346142357
#   :	:
#   (27265, 4)	0.6025827181224164
#   (27265, 18)	0.7980564314759957
#   (27266, 4)	1.0
#   (27267, 4)	0.786066521250593
#   (27267, 7)	0.6181419126454628
#   (27268, 4)	0.6025827181224164
#   (27268, 18)	0.7980564314759957
#   (27269, 2)	0.8909340356345918
#   (27269, 4)	0.4541327384673561
#   (27270, 1)	0.41915098224772934
#   (27270, 2)	0.5182685890892543
#   (27270, 3)	0.5057418311427628
#   (27270, 4)	0.26417526349980835
#   (27270, 8)	0.47973612958726514
#   (27271, 4)	1.0
#   (27272, 4)	0.5460379159242152
#   (27272, 12)	0.8377604636011059
#   (27273, 4)	1.0
#   (27274, 4)	1.0
#   (27275, 1)	1.0
#   (27276, 11)	0.7071067811865476
#   (27276, 14)	0.7071067811865476
#   (27277, 1)	0.5551245384251795
#   (27277, 8)	0.6353636488572378
#   (27277, 12)	0.5367958462479454

# %%
from .base_recommender import MovieRecommenderBase
import numpy as np

class StarRatingRecommender(MovieRecommenderBase):
    def __init__(self, data_path='data/movie.csv'):
        """
        Recommender that uses 5-star rating system
        """
        super().__init__(data_path)


    def _process_user_preferences(self, user_preferences):
        """
        Process user preferences with 5-star ratings
        
        Parameters:
        - user_preferences: dict with 'ratings' as a list of tuples (movie_title, rating)
                            where rating is 1-5 stars
        
        Returns:
        - combined_sim_scores: numpy array of combined similarity scores
        - total_weight: total weight of all ratings
        """
        combined_sim_scores = np.zeros(self.sim_matrix.shape[0])
        total_weight = 0
        
        for movie_title, rating in user_preferences:
            if movie_title in self.title_to_indices:
                # Convert rating to weight (1-5 stars to 0.2-1.0 scale)
                weight = (rating - 1) / 4  # Normalize to 0-1 range
                
                for idx in self.title_to_indices[movie_title]:
                    # Apply weighted influence (positive for ratings > 3, negative for < 3)
                    influence = (weight - 0.5) * 2  # Convert to -1 to +1 range
                    combined_sim_scores += self.sim_matrix[idx] * influence
                    total_weight += abs(influence)
        
        # Normalize by total weight if any ratings were processed
        if total_weight > 0:
            combined_sim_scores /= total_weight
            
        return combined_sim_scores, total_weight

    def get_personalized_recommendations(self, user_preferences, top_n=5, genre_diversity=True):
        """
        Get recommendations based on star ratings
        
        Parameters:
        - user_preferences: dict with 'ratings' list of (movie_title, rating) tuples
        - top_n: number of recommendations
        - genre_diversity: whether to ensure genre variety
        
        Returns:
        - DataFrame with recommended movies
        """
        user_preferences_filtered = self._convert_id_to_title(user_preferences)
        combined_sim_scores, _ = self._process_user_preferences(user_preferences_filtered)
        
        # Get all rated movie titles to exclude from recommendations
        all_rated_movies = set()
        for movie_title, _ in user_preferences_filtered:
            if movie_title in self.title_to_indices:
                all_rated_movies.add(movie_title)
        
        # Get and sort similarity scores
        sim_scores = list(enumerate(combined_sim_scores))
        sim_scores.sort(key=lambda x: x[1], reverse=True)
        
        # Generate recommendations
        recommendations = []
        selected_genres = set()
        
        for i, score in sim_scores:
            if len(recommendations) >= top_n:
                break
                
            movie_data = self.movies.iloc[i]
            title = movie_data['title']
            genres = set(movie_data['genres'].split('|'))
            
            # Skip already rated movies
            if title in all_rated_movies:
                continue
                
            # Apply genre diversity if enabled
            if genre_diversity:
                if not genres.issubset(selected_genres):
                    recommendations.append(i)
                    selected_genres.update(genres)
            else:
                recommendations.append(i)
        
        # Format output
        result = self.movies.iloc[recommendations][['movieId', 'title', 'genres', 'year']]
        result['genres'] = result['genres'].str.replace('|', ', ')
        return result.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class StarRatingRecommender(MovieRecommenderBase):
#       2     def __init__(self, data_path='data/movie.csv'):
#       3         """
#       4         Recommender that uses 5-star rating system
#       5         """
#
# NameError: name 'MovieRecommenderBase' is not defined

# %% [markdown]
# PROVES

# %%
data_path = '../src/data/movie.csv'

# 1. Demonstrate Star Rating Recommender
print("\n=== STAR RATING RECOMMENDER ===")
star_rec = StarRatingRecommender(data_path=data_path)

# Example ratings (movie_title, rating) where rating is 1-5 stars
user_ratings = {
    'ratings': [
        ('Toy Story', 1),  # Loved it
        ('Jumanji', 2),    # Liked it
        ('GoldenEye', 4),   # Didn't like it
        ('Richard III', 5)  # Hated it
    ]
}

user_ratings = {
    'ratings': [
        ('0', 1),  # Loved it
        ('1', 2),    # Liked it
        ('9', 4),   # Didn't like it
        ('40', 5)  # Hated it
    ]
}

print("\nTop 5 Recommended Movies (based on star ratings):")
star_recommendations = star_rec.get_personalized_recommendations(user_ratings)
print(star_recommendations)
# Out:
# === STAR RATING RECOMMENDER ===
#
# Top 5 Recommended Movies (based on star ratings):
#    movieId                title                genres    year
# 0       73      Misérables, Les            Drama, War  1995.0
# 1      161         Crimson Tide  Drama, Thriller, War  1995.0
# 2      110           Braveheart    Action, Drama, War  1995.0
# 3      665          Underground    Comedy, Drama, War  1995.0
# 4      389  Colonel Chabert, Le   Drama, Romance, War  1994.0
# C:\Users\janpl\AppData\Local\Temp\ipykernel_20876\1827069251.py:51: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return self.movies.groupby('title').apply(lambda x: list(x.index)).to_dict()

# %%
star_rec.movies[star_rec.movies['movieId'] == 2]['title'].values[0]
# Out:
# 'Jumanji'

# %%
for movie in star_rec.title_to_indices.items():
    # if len(movie[1]) > 1:
        if 9 in movie[1]:
            print(movie)
# Out:
# ('GoldenEye', [9])

# %%
star_rec.movies
# Out:
#        movieId                                         title_year  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# ...        ...                                                ...
# 27027   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27028   131254                       Kein Bund für's Leben (2007)
# 27029   131256                      Feuer, Eis & Dosenbier (2002)
# 27030   131258                                 The Pirates (2014)
# 27031   131262                                   Innocence (2014)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 27027                                Comedy|Horror
# 27028                                       Comedy
# 27029                                       Comedy
# 27030                                    Adventure
# 27031                     Adventure|Fantasy|Horror
#
#                                                  title    year
# 0                                            Toy Story  1995.0
# 1                                              Jumanji  1995.0
# 2                                     Grumpier Old Men  1995.0
# 3                                    Waiting to Exhale  1995.0
# 4                          Father of the Bride Part II  1995.0
# ...                                                ...     ...
# 27027  Forklift Driver Klaus: The First Day on the Job  2001.0
# 27028                            Kein Bund für's Leben  2007.0
# 27029                           Feuer, Eis & Dosenbier  2002.0
# 27030                                      The Pirates  2014.0
# 27031                                        Innocence  2014.0
#
# [27032 rows x 5 columns]

# %%
star_rec.title_to_indices
# Out:
# {'#chicagoGirl: The Social Network Takes on a Dictator': [23490],
#  '$ (Dollars)': [16833],
#  '$5 a Day': [15836],
#  '$9.99': [14876],
#  '$ellebrity (Sellebrity)': [22366],
#  "'71": [24921],
#  "'Hellboy': The Seeds of Creation": [19743],
#  "'Human' Factor, The (Human Factor, The)": [23049],
#  "'Neath the Arizona Skies": [13981],
#  "'R Xmas": [16155],
#  "'Round Midnight": [8924],
#  "'Salem's Lot": [9462],
#  "'Til There Was You": [766],
#  "'Twas the Night Before Christmas": [20760],
#  "'burbs, The": [1988],
#  "'night Mother": [3025],
#  '(500) Days of Summer': [13916],
#  '(A)sexual': [24302],
#  '(Untitled)': [15918],
#  '*batteries not included': [7684],
#  '+1': [22540],
#  '...All the Marbles (California Dolls, The)': [5607],
#  '...And God Spoke': [6490],
#  '...And Justice for All': [3331],
#  '...tick... tick... tick...': [8693],
#  '.45': [12365],
#  '009 Re: Cyborg': [20772],
#  '1': [23814, 26631],
#  '1, 2, 3, Sun (Un, deuz, trois, soleil)': [8093],
#  '1-900 (06)': [872],
#  '10': [6548],
#  '10 000 timmar': [26560],
#  '10 Items or Less': [11457],
#  '10 MPH': [14668],
#  '10 Mountains 10 Years': [18744],
#  '10 Questions for the Dalai Lama': [12293],
#  '10 Rillington Place': [7622],
#  '10 Things I Hate About You': [2487],
#  '10 Years': [19890],
#  '10 minutes (10 minuta)': [24336],
#  '10 to Midnight': [6069],
#  '10,000 BC': [12485],
#  '10.000 Km (Long Distance)': [23404],
#  '10.5': [23724],
#  '10.5: Apocalypse': [12356],
#  '100 Bloody Acres': [26470],
#  '100 Feet': [13001],
#  '100 Girls': [7362],
#  '100 Men and a Girl (One Hundred Men and a Girl)': [14417],
#  '100 Rifles': [12699],
#  '100 Ways to Murder Your Wife (Sha qi er ren zu)': [20063],
#  '100 Years at the Movies': [26087],
#  '100 Years of Evil': [21137],
#  '1000 Eyes of Dr. Mabuse, The (Die 1000 Augen des Dr. Mabuse)': [7695],
#  '1001 Nights': [26150],
#  '101 Dalmatians': [1336],
#  '101 Dalmatians (One Hundred and One Dalmatians)': [2001],
#  "101 Dalmatians II: Patch's London Adventure": [25552],
#  '101 Reykjavik (101 Reykjavík)': [6245],
#  '102 Dalmatians': [3897],
#  '102 Minutes That Changed America': [21742],
#  '1066': [14878],
#  '10th & Wolf': [12161],
#  "10th Judicial Court: Judicial Hearings, The (10e chambre - Instants d'audience)": [12458],
#  '10th Kingdom, The': [9250],
#  '10th Victim, The (La decima vittima)': [4339],
#  '11 Flowers (Wo 11)': [20146],
#  '11 Harrowhouse': [10138],
#  '11 x 14': [18063],
#  '11\'09\\\\"01 - September 11 (2002)"': [7481],
#  '11-11-11 (11-11-11: The Prophecy)': [18168],
#  '11.6': [22861],
#  '112 Weddings': [23589],
#  '11:14': [9422],
#  '11th Hour, The': [13441],
#  '12': [12248],
#  '12 Angry Men': [1178, 15253],
#  '12 Dates of Christmas': [25261],
#  '12 Days of Terror': [18283],
#  '12 Dogs of Christmas, The': [18265],
#  "12 O'Clock Boys": [23433],
#  '12 Rounds': [14022],
#  '12 Rounds 2: Reloaded': [22447],
#  '12 Storeys (Shier lou)': [16081],
#  '12 Years a Slave': [21918],
#  '120': [13891],
#  '127 Hours': [16118],
#  '12:01': [13386],
#  '12:01 PM': [26614],
#  '12:08 East of Bucharest (A fost sau n-a fost?)': [12025],
#  '12th & Delaware': [15705],
#  '13': [16289],
#  '13 Assassins (Jûsan-nin no shikaku)': [16997],
#  '13 Beloved (13 game sayawng)': [12930],
#  '13 Fighting Men': [22856],
#  '13 Frightened Girls! (Candy Web, The)': [23515],
#  '13 Ghosts': [4696],
#  '13 Going on 30': [7318],
#  '13 Lakes': [26428],
#  '13 Rue Madeleine': [6328],
#  '13 Sins': [23120],
#  '13 Tzameti': [11411],
#  '13/13/13': [23302],
#  '13B': [13565],
#  '13Hrs': [16102],
#  '13th Letter, The': [14390],
#  '13th Warrior, The': [2740],
#  '14 Blades (Jin yi wei)': [18467],
#  '14 Hours (Fourteen Hours)': [10298],
#  '1408': [11964],
#  '1492: Conquest of Paradise': [8222],
#  '15': [17078],
#  '15 Minutes': [4073],
#  '16 Acres': [23208],
#  '16 Blocks': [10864],
#  '16 Years of Alcohol': [10427],
#  '16 to Life': [19705],
#  '1612: Khroniki smutnogo vremeni': [17112],
#  '17 Again': [13644],
#  '17 Girls (17 filles)': [23552],
#  '1776': [5375],
#  '18 Again!': [4367],
#  '18 Fingers of Death!': [20748],
#  '18 Years Later (Diciotto anni dopo)': [18906],
#  "18 Years Old and Rising (J'aime regarder les filles)": [22572],
#  '180° South (180 Degrees South) (180° South: Conquerors of the Useless)': [21009],
#  '187 (One Eight Seven)': [1556],
#  '1900 (Novecento)': [8794],
#  '1911 (Xinhai geming)': [20018],
#  "1939: Hollywood's Greatest Year": [13924],
#  '1941': [6992],
#  '1969': [4368],
#  '1971': [24082],
#  '1981': [25133],
#  '1984': [13013],
#  '1984 (Nineteen Eighty-Four)': [2033],
#  '1987': [25134],
#  '1990: The Bronx Warriors (1990: I guerrieri del Bronx)': [16143],
#  '1991: The Year Punk Broke': [12049],
#  '19th Wife, The': [17170],
#  '1½ Knights - In Search of the Ravishing Princess Herzelinde': [24861],
#  '2 + 2 (Dos más dos)': [22615],
#  '2 Become 1 (Tin sun yut dui)': [20453],
#  '2 Days in New York': [19246],
#  '2 Days in Paris': [12068],
#  '2 Days in the Valley': [980],
#  '2 Fast 2 Furious (Fast and the Furious 2, The)': [6277],
#  '2 Guns': [21384],
#  "2 ou 3 choses que je sais d'elle (2 or 3 Things I Know About Her)": [1141],
#  '2-Headed Shark Attack': [19558],
#  '20 Dates': [2407],
#  '20 Feet from Stardom (Twenty Feet from Stardom)': [21142],
#  '20 Million Miles to Earth': [5371],
#  '20 Seconds of Joy': [17263],
#  '20 Years After': [26967],
#  '20,000 Days on Earth': [24031],
#  '20,000 Leagues Under the Sea': [1000, 13045, 20908, 24047],
#  '20,000 Years in Sing Sing': [11469],
#  '200 Cigarettes': [2419],
#  '200 M.P.H.': [17459],
#  '200 Motels': [10410],
#  '2001 Maniacs': [11687],
#  '2001: A Space Odyssey': [907],
#  '2009: Lost Memories': [9743],
#  '2010: Moby Dick': [19248],
#  '2010: The Year We Make Contact': [2226],
#  '2012': [14458],
#  '2012: Supernova': [15872],
#  '2012: Time for Change': [16610],
#  '2013 Rock and Roll Hall of Fame Induction Ceremony, The': [22400],
#  "2016: Obama's America": [19565],
#  '2019: After the Fall of New York': [18042],
#  '2046': [9255],
#  '2081': [24003],
#  '20th Century Boys - Chapter 1: Beginning of the End': [24784],
#  '21': [12551],
#  '21 Grams': [6841],
#  '21 Hours at Munich': [26908],
#  '21 Jump Street': [18778],
#  '21 Up': [11830],
#  '21 and Over': [20511],
#  '21 tapaa pilata avioliitto': [20480],
#  '21-87': [25251],
#  "22 Bullets (L'immortel)": [15839],
#  '22 Jump Street': [23537],
#  '23 (23 - Nichts ist so wie es scheint)': [10995],
#  '23 Paces to Baker Street': [14391],
#  '24 7: Twenty Four Seven': [2359],
#  '24 City (Er shi si cheng ji)': [16993],
#  '24 Exposures': [23402],
#  '24 Hour Party People': [5411],
#  '24 Hour Woman, The': [2401],
#  '24 Hours on Craigslist': [22025],
#  '247°F': [19502],
#  '24: Redemption': [15452],
#  '24th Day, The': [10316],
#  '25 Watts': [10098],
#  '25th Hour': [5855],
#  '27 Club, The': [14733],
#  '27 Dresses': [12344],
#  '27 Missing Kisses': [12114],
#  '28 Days': [3443],
#  '28 Days Later': [6392],
#  '28 Hotel Rooms': [19855],
#  '28 Up': [7369],
#  '28 Weeks Later': [11861],
#  '29 Palms': [21941],
#  '29th Street': [7652],
#  '2:13': [15627],
#  '2:22': [20710],
#  '2:37': [11235],
#  '2AM: The Smiling Man': [23939],
#  '2LDK': [9470],
#  '3 A.M.': [19064],
#  '3 Backyards': [17570],
#  '3 Bad Men': [12391],
#  '3 Blind Mice': [11399],
#  '3 Days to Kill': [22920],
#  '3 Extremes (Three... Extremes) (Saam gaang yi)': [10191],
#  '3 Godfathers': [8493],
#  '3 Holiday Tails (Golden Christmas 2: The Second Tail, A)': [23307],
#  '3 Idiots': [14775],
#  '3 Little Ninjas and the Lost Treasure': [22036],
#  '3 Needles': [15605],
#  '3 Ninjas': [4652],
#  '3 Ninjas Kick Back': [4653],
#  '3 Ninjas Knuckle Up': [4654],
#  '3 Ninjas: High Noon On Mega Mountain': [1677],
#  '3 Penny Opera, The (Threepenny Opera, The) (3 Groschen-Oper, Die)': [9870],
#  '3 Ring Circus': [14239],
#  '3 Rooms of Melancholia, The (Melancholian 3 huonetta)': [10531],
#  '3 Sailors and a Girl (Three Sailors and a Girl)': [15226],
#  '3 Simoa': [25434],
#  '3 Strikes': [3235],
#  '3 Women (Three Women)': [7727],
#  '3 Worlds of Gulliver, The': [14240],
#  '3 dev adam (Three Giant Men)': [21409],
#  '3 on a Couch (Three on a Couch)': [13850],
#  '3, 2, 1... Frankie Go Boom (Frankie Go Boom)': [19738],
#  '3-Iron (Bin-jip)': [9585],
#  '30 Beats': [20721],
#  '30 Days of Night': [12145],
#  '30 Days of Night: Dark Days': [16037],
#  '30 Minutes or Less': [17661],
#  '30 Years to Life': [5174],
#  '300': [11707],
#  '300 Miles to Heaven (300 Mil do Nieba)': [10101],
#  '300 Spartans, The': [11129],
#  '3000 Miles to Graceland': [4065],
#  '300: Rise of an Empire': [22950],
#  '301, 302 (301/302)': [644],
#  '3096 Days': [21062],
#  '31 North 62 East': [15528],
#  '33 Postcards': [19342],
#  '33 Scenes from Life (33 sceny z zycia)': [13434],
#  '35 Shots of Rum (35 rhums)': [14386],
#  '35 Up': [9003],
#  '35 and Ticking': [17512],
#  '36 Crazy Fists (San shi liu mi xing quan)': [19961],
#  '36 Hours': [8616],
#  '36 Quai des Orfèvres (Department 36)': [11252],
#  '36 fillette': [7512],
#  '360': [19487],
#  '36th Chamber of Shaolin, The (Shao Lin san shi liu fang) (Master Killer)': [11665],
#  '388 Arletta Avenue': [19280],
#  '39 Steps, The': [948],
#  '3:10 to Yuma': [5203, 12089],
#  '3rd Voice, The': [15227],
#  '3rd World Hero (Bayaning Third World)': [18970],
#  '3some (Castillos de cartón)': [20644],
#  '4': [10448],
#  '4 Horsemen of the Apocalypse, The': [8587],
#  '4 Little Girls': [4123],
#  '4 Months, 3 Weeks and 2 Days (4 luni, 3 saptamâni si 2 zile)': [12100],
#  '4 for Texas': [4961],
#  '4.3.2.1': [19151],
#  '40 Days and 40 Nights': [5055],
#  '40 Guns to Apache Pass': [14408],
#  '40 Pounds of Trouble': [18470],
#  '40-Year-Old Virgin, The': [10347],
#  '400 Blows, The (Les quatre cents coups)': [2645],
#  '41': [21129],
#  '41-Year-Old Virgin Who Knocked Up Sarah Marshall and Felt Superbad About It, The': [15365],
#  '42': [20821],
#  '42 Up': [2990],
#  '42nd Street': [6968],
#  '44 Inch Chest': [14941],
#  '44 Minutes: The North Hollywood Shoot-Out': [9986],
#  '44500 Max': [16722],
#  '47  Ronin (Shijûshichinin no shikaku)': [22568],
#  '47 Ronin': [22102],
#  '47 Ronin, The (Genroku Chûshingura)': [8440],
#  '47 Samurai (Chûshingura) (Loyal 47 Ronin, The)': [3005],
#  '48 Hrs.': [4953],
#  '48 Shades': [17324],
#  '49 Up': [11593],
#  '49th Parallel': [10743],
#  '4:44 Last Day on Earth': [18844],
#  '4th Floor, The': [9211],
#  '4th Man, The (Fourth Man, The) (Vierde man, De)': [8878],
#  '5 Against the House': [13849],
#  '5 Broken Cameras': [19805],
#  '5 Centimeters per Second (Byôsoku 5 senchimêtoru)': [13268],
#  '5 Days of War': [19091],
#  '5 Deadly Venoms, The (Wu du) (Five Deadly Venoms)': [8822],
#  "5 Dolls for an August Moon (5 bambole per la luna d'agosto)": [14245],
#  '5 Fingers': [11418],
#  '5,000 Fingers of Dr. T, The': [4199],
#  '50 Children: The Rescue Mission of Mr. And Mrs. Kraus': [20811],
#  '50 First Dates': [7181],
#  '50 Worst Movies Ever Made, The': [24154],
#  '50/50': [17897],
#  '51': [24163],
#  '51 Birch Street': [12531],
#  '52 Pick-Up': [2390],
#  '52 Tuesdays': [24598],
#  '54': [2104],
#  '55 Days at Peking': [10485],
#  '56 Up': [19716],
#  '588 Rue Paradis (Mother)': [19629],
#  '5th Day of Peace (Dio è con noi)': [14357],
#  '5th Musketeer, The (a.k.a. Fifth Musketeer, The)': [8086],
#  '5x2': [9801],
#  '6 Bullets': [19421],
#  '6 Days to Air: The Making of South Park': [19398],
#  '6 Desires: DH Lawrence and Sardinia': [26341],
#  '6 Souls (Shelter)': [16026],
#  '61*': [9308],
#  '633 Squadron': [6329],
#  '66 Scenes From America': [26765],
#  '6954 Kilometriä Kotiin': [21615],
#  '6ixtynin9 (Ruang Talok 69)': [9277],
#  '6th Day, The': [3892],
#  '6th Man, The (Sixth Man, The)': [6316],
#  '7 Below (Seven Below)': [19598],
#  '7 Boxes (7 cajas)': [22894],
#  '7 Days (Les 7 jours du talion)': [16025],
#  '7 Days in Havana': [26200],
#  '7 Dollars on the Red (Sette dollari sul rosso)': [15232],
#  '7 Dwarves: The Forest Is Not Enough': [27007],
#  '7 Faces of Dr. Lao': [10728],
#  '7 Khoon Maaf': [20098],
#  '7 Men from Now (Seven Men from Now)': [11245],
#  '7 Plus Seven': [11598],
#  '7 Seconds': [10665],
#  '7 Virgins (7 vírgenes)': [16376],
#  '7 Women (a.k.a. Seven Women)': [14126],
#  '700 Sundays': [24085],
#  '71 Fragments of a Chronology of Chance (71 Fragmente einer Chronologie des Zufalls)': [9088],
#  '711 Ocean Drive': [21799],
#  '71: Into The Fire (Pohwasogeuro)': [16828],
#  '7500': [23486],
#  '7th Cavalry (Seventh Cavalry)': [22183],
#  '7th Dawn, The': [14358],
#  '7th Floor': [25287],
#  '7th Heaven (Seventh Heaven)': [13920],
#  '7th Voyage of Sinbad, The': [3066],
#  '8 (8, the Play)': [23007],
#  '8 1/2 (8½)': [1223],
#  '8 Days to Premiere (8 päivää ensi-iltaan)': [23587],
#  '8 Diagram Pole Fighter, The (a.k.a. Invincible Pole Fighter) (Wu Lang ba gua gun)': [16770],
#  '8 Heads in a Duffel Bag': [1460],
#  '8 Mile': [5711],
#  '8 Million Ways to Die': [10666],
#  '8 Seconds': [404],
#  '8 Women': [5514],
#  '8 ½ Women (a.k.a. 8 1/2 Women) (a.k.a. Eight and a Half Women)': [3535],
#  '800 Bullets (800 Balas)': [9902],
#  '84 Charing Cross Road': [5307],
#  '88 Minutes': [11887],
#  '8: The Mormon Proposition': [15599],
#  '8:28 am (8 Uhr 28)': [17240],
#  '8:46': [20939],
#  '8MM': [2420],
#  '8MM 2': [10785],
#  '8th Wonderland': [15785],
#  '9': [14159, 24433],
#  '9 1/2 Weeks (Nine 1/2 Weeks)': [3616],
#  '9 Month Stretch (9 mois ferme)': [22162],
#  '9 Songs': [10130],
#  '9 Souls (Nain souruzu)': [10107],
#  '9 Star Hotel (Malon 9 Kochavim)': [12536],
#  '9/11': [10970],
#  '90 Minutes (90 minutter)': [21354],
#  '911 in Plane Site': [20578],
#  '9500 Liberty': [20648],
#  '96 Minutes': [18991],
#  '97 Percent True': [19918],
#  '976-EVIL': [5449],
#  '976-EVIL II': [20157],
#  '99 Homes': [26345],
#  '99 River Street': [14407],
#  '99 and 44/100% Dead': [18281],
#  '99 francs': [12589],
#  '9th Company': [11406],
#  '9to5: Days in Porn (a.k.a. 9 to 5: Days in Porn)': [13958],
#  'A Blank on the Map': [26751],
#  'A Bright Shining Lie': [26861],
#  'A Chairy Tale': [25157],
#  'A Chinese in a Coma': [25511],
#  'A Christmas Kiss': [26528],
#  'A Cinderella Story: Once Upon a Song': [25056],
#  'A Coming-Out Party': [21220],
#  "A Connecticut Yankee in King Arthur's Court": [24826],
#  'A Cry in the Wild': [25567],
#  'A Flintstones Christmas Carol': [26119],
#  'A Follower for Emily': [25197],
#  'A Fugitive from the Past': [26750],
#  'A Gathering of Eagles': [16503],
#  'A Girl Walks Home Alone at Night': [25132],
#  'A Good Marriage': [24679],
#  'A Grain of Truth': [26421],
#  'A Gun for Jennifer': [26694],
#  'A Home at the End of the World': [7984],
#  "A House of Secrets: Exploring 'Dragonwyck'": [26987],
#  'A Husband of Round Trip': [25126],
#  'A Justified Life: Sam Peckinpah and the High Country': [25021],
#  'A Kind of America 2': [24782],
#  'A Lesson Before Dying': [25895],
#  'A Life in Dirty Movies': [25595],
#  'A Magnificent Haunting': [26875],
#  'A Man Called Magnum': [25069],
#  'A Master Builder': [25424],
#  "A Matador's Mistress": [24781],
#  'A Matter of Size': [24949],
#  "A Merry Friggin' Christmas": [25336],
#  'A Most Violent Year': [25141],
#  'A Mulher Invisível': [22847],
#  'A Night at the Movies: The Horrors of Stephen King': [25496],
#  'A Night at the Movies: The Suspenseful World of Thrillers': [25497],
#  'A Night for Dying Tigers': [25543],
#  'A Night in the Show': [24492],
#  'A One-Way Trip to Antibes': [26640],
#  'A Patriotic Man': [25541],
#  'A Phantasy': [25160],
#  'A Pigeon Sat on a Branch Reflecting on Existence': [26402],
#  'A Pistol For Ringo': [25097],
#  'A Promise': [24827],
#  'A Run for Your Money': [10726],
#  'A Second Chance': [27018],
#  'A Short History of Decay': [26708],
#  'A Smoky Mountain Christmas': [25124],
#  'A Spell to Ward Off the Darkness': [26235],
#  'A Star Athlete': [24564],
#  'A Story of Children and Film': [26343],
#  'A Summer in La Goulette': [26702],
#  'A Summer in St. Tropez': [25397],
#  'A Thousand Times Goodnight': [25256],
#  'A Via Láctea': [17823],
#  'A Viking Saga: The Darkest Day': [25252],
#  'A Walk in the Old City of Warsaw': [25519],
#  'A Walk in the Woods': [26327],
#  'A mí las mujeres ni fu ni fa': [23661],
#  'A-Haunting We Will Go': [14275],
#  'A-Team, The': [15397],
#  'A.C.O.D.': [22451],
#  'A.I. Artificial Intelligence': [4275],
#  'A.K.': [10732],
#  'A.K.A. Don Bonus': [20517],
#  'ABBA: The Movie': [8809],
#  'ABC Africa': [17956],
#  'ABCs of Death, The': [20479],
#  'AKA': [8212],
#  'AM1200': [21148],
#  'ATF': [21294],
#  'ATL': [10950],
#  'ATM': [19411],
#  'AVP: Alien vs. Predator': [8127],
#  'AVPR: Aliens vs. Predator - Requiem': [12328],
#  'Aaja Nachle': [14636],
#  'Aakrosh': [18928],
#  'Aaltra': [11327],
#  'Aamir': [13669],
#  'Aankhen': [16655],
#  'Aaron Loves Angela': [23999],
#  'Aashiqui 2': [24767],
#  'Abandon': [5578],
#  'Abandon Ship! (Seven Waves Away)': [14089],
#  'Abandoned': [15824],
#  'Abandoned, The': [11708],
#  'Abbott and Costello Go to Mars': [9654],
#  'Abbott and Costello Meet Captain Kidd': [14291],
#  'Abbott and Costello Meet Dr. Jekyll and Mr. Hyde': [8527],
#  'Abbott and Costello Meet Frankenstein': [3835],
#  'Abbott and Costello Meet the Invisible Man': [9653],
#  'Abbott and Costello Meet the Keystone Kops': [14299],
#  'Abbott and Costello Meet the Killer, Boris Karloff': [9655],
#  'Abbott and Costello Meet the Mummy': [4671],
#  'Abbott and Costello in Hollywood': [14284],
#  'Abbott and Costello in the Foreign Legion': [14285],
#  'Abduction': [18056],
#  'Abe Lincoln in Illinois': [8433],
#  'Abelar: Tales of an Ancient Empire (Tales of an Ancient Empire)': [16161],
#  'Abendland': [20664],
#  'Aberdeen': [4634],
#  "Abigail's Party": [14759],
#  'Abols Upe': [21300],
#  'Abominable': [17065],
#  'Abominable Dr. Phibes, The': [4101],
#  'Abominable Snowman, The (Abominable Snowman of the Himalayas, The)': [3557],
#  'Abouna': [10699],
#  'About Adam': [3769],
#  'About Alex': [26796],
#  'About Cherry': [20951],
#  'About Elly (Darbareye Elly)': [15033],
#  'About Face: Supermodels Then and Now': [20803],
#  'About Last Night': [22864],
#  'About Last Night...': [2177],
#  'About Schmidt': [5846],
#  'About Time': [21502],
#  'About a Boy': [5280],
#  'Above Suspicion': [5920, 17643],
#  'Above Us Only Sky': [25614],
#  'Above and Beyond': [15811],
#  'Above the Law': [4371],
#  'Above the Rim': [405],
#  'Above the Street, Below the Water (Over gaden under vandet)': [20537],
#  'Abraham': [12040],
#  'Abraham Lincoln': [20691],
#  'Abraham Lincoln: Vampire Hunter': [19147],
#  "Abraham's Valley (Vale Abraão)": [5905],
#  'Absence of Malice': [5608],
#  'Absent (Ausente)': [22078],
#  'Absent-Minded Professor, The': [1931],
#  'Absentia': [18847],
#  'Absolon': [9376],
#  'Absolute Aggression': [26870],
#  'Absolute Beginners': [6247],
#  'Absolute Giganten': [12905],
#  'Absolute Power': [1422],
#  'Absurdistan': [14859],
#  'Abyss, The': [1104],
#  'Acacia': [10322],
#  'Acacias, Las': [20201],
#  "Acadia Acadia?!? (L'acadie, l'Acadie)": [17464],
#  'Acapulco, First Beach... To the Left': [25323],
#  'Accattone': [6489],
#  'Accepted': [11237],
#  'Accident': [7000],
#  'Accident (Yi ngoi)': [15721],
#  'Accident on Hill Road': [15473],
#  'Accidental Golfer, The (Den ofrivillige golfaren)': [21295],
#  'Accidental Husband, The': [13033],
#  'Accidental Spy, The (Dak miu mai shing)': [9324],
#  'Accidental Tourist, The': [4369],
#  'Accidents Happen': [18287],
#  'Accomplices (Complices)': [20645],
#  'According to Greta': [15720],
#  'According to Spencer': [20804],
#  'Accused (Anklaget)': [12991],
#  'Accused, The': [4370],
#  'Ace Attorney (Gyakuten saiban)': [20773],
#  "Ace High (Quattro dell'Ave Maria, I)": [13046],
#  'Ace Ventura: Pet Detective': [340],
#  'Ace Ventura: When Nature Calls': [18],
#  'Ace in the Hole (Big Carnival, The)': [3645],
#  "Ace of Aces (a.k.a. Super Ace, The) (As des as, L')": [5821],
#  'Ace of Hearts': [13200],
#  'Ace of Hearts, The': [11053],
#  "Aces 'N' Eights": [20912],
#  'Aces High': [14333],
#  'Aces and Eights': [15233],
#  'Aces: Iron Eagle III': [2731],
#  'Achilles and the Tortoise (Akiresu to kame)': [15172],
#  'Acid House, The': [2679],
#  'Acla, The Descent into Floristella (La discesa di Aclà a Floristella)': [15440],
#  'Across 110th Street': [4811],
#  'Across the Bridge': [25421],
#  'Across the Hall': [17209],
#  'Across the Line: The Exodus of Charlie Wright': [19012],
#  'Across the Pacific': [8446],
#  'Across the Sea of Time': [36],
#  'Across the Tracks': [9005],
#  'Across the Universe': [11989],
#  'Across the Wide Missouri': [20833],
#  'Across to Singapore': [23104],
#  'Act in Question, The (Acto en cuestión, El)': [20393],
#  'Act of Aggression': [26377],
#  'Act of Killing, The': [20526],
#  "Act of Seeing with One's Own Eyes, The": [20584],
#  'Act of Valor': [18728],
#  'Act of Violence': [10041],
#  'Action Jackson': [3619, 25101],
#  'Action in the North Atlantic': [8454],
#  "Actor's Revenge, An (Yukinojô henge)": [3442],
#  'Actress, The': [16053],
#  'Actress, the Dollars and the Transylvanians, The (Artista, dolarii si Ardelenii)': [14730],
#  'Actresses (Actrices)': [18132],
#  'Acts of Worship': [10037],
#  'Adam': [14058],
#  'Adam & Paul': [11822],
#  'Adam & Steve': [11090],
#  'Adam Had Four Sons': [16831],
#  'Adam Resurrected': [15288],
#  'Adam and Dog': [25488],
#  'Adam and Eve (Adão e Eva)': [22697],
#  "Adam's Apples (Adams æbler)": [11232],
#  "Adam's Rib": [7009],
#  'Adanggaman': [4354],
#  'Adaptation': [5803],
#  'Addams Family Reunion': [9188],
#  'Addams Family Values': [406],
#  'Addams Family, The': [2040],
#  'Addicted': [20160],
#  'Addicted to Love': [1491],
#  'Addicted to Plastic': [26469],
#  'Addiction, The': [150],
#  'Address Unknown (Suchwiin bulmyeong)': [10676],
#  'Adelheid': [16018],
#  'Adios Carmen': [26691],
#  'Adios Sabata': [13054],
#  'Adjust Your Tracking': [26468],
#  'Adjuster, The': [11100],
#  'Adjustment Bureau, The': [16801],
#  'Admiral': [13096],
#  'Admiral Yamamoto': [18833],
#  'Admission': [20743],
#  'Admissions': [24853],
#  'Adonis Factor, The': [20468],
#  'Adopted': [17616],
#  'Adoration': [14092],
#  'Adore': [21566],
#  'Adrenalin: Fear the Rush': [1352],
#  'Adrenaline Drive (Adorenarin doraibu)': [9240],
#  'Adrift (Choi Voi)': [16228],
#  'Adrift (À Deriva)': [15405],
#  'Adrift in Tokyo (Tenten)': [16784],
#  'Adult Camp': [26591],
#  'Adult World': [22809],
#  'Adulthood': [15362],
#  'Advance to the Rear': [24039],
#  'Advanced Style': [24626],
#  'Advantageous': [26350],
#  'Adventure in Baltimore': [19955],
#  'Adventure in Space and Time, An': [22264],
#  "Adventure of Sherlock Holmes' Smarter Brother, The": [8776],
#  'Adventureland': [13591],
#  'Adventurer, The': [10102],
#  'Adventurer: The Curse of the Midas Box, The': [24212],
#  'Adventures in Babysitting': [2049],
#  'Adventures in Zambezia': [21740],
#  "Adventures of Arsène Lupin, The (Aventures d'Arsène Lupin, Les)": [22587],
#  'Adventures of Baron Munchausen, The': [4372],
#  'Adventures of Buckaroo Banzai Across the 8th Dimension, The': [2983],
#  'Adventures of Captain Marvel': [18781],
#  'Adventures of Don Juan': [11248],
#  'Adventures of Elmo in Grouchland, The': [2800],
#  'Adventures of Felix, The (a.k.a. Funny Felix) (Drôle de Félix)': [4280],
#  'Adventures of Food Boy, The (aka High School Superhero)': [13510],
#  'Adventures of Ford Fairlane, The': [7081],
#  'Adventures of Hajji Baba, The': [22952],
#  'Adventures of Huck Finn, The': [4980],
#  'Adventures of Huckleberry Finn, The': [6637, 13089],
#  'Adventures of Ichabod and Mr. Toad, The': [3870],
#  "Adventures of Kitty O'Day (Kitty O'Day Comes Through)": [21759],
#  'Adventures of Mark Twain, The': [10206, 11851],
#  'Adventures of Mary-Kate and Ashley, The: The Case of the Christmas Caper': [19243],
#  'Adventures of Mary-Kate and Ashley, The: The Case of the United States Navy Adventure': [19244],
#  'Adventures of Milo and Otis, The (Koneko monogatari)': [2760],
#  'Adventures of Picasso, The (Picassos äventyr)': [8830],
#  'Adventures of Pinocchio, The': [813],
#  'Adventures of Pluto Nash, The': [5426],
#  'Adventures of Power': [16361],
#  'Adventures of Prince Achmed, The (Abenteuer des Prinzen Achmed, Die)': [10557],
#  'Adventures of Priscilla, Queen of the Desert, The': [341],
#  'Adventures of Robin Hood, The': [923],
#  'Adventures of Rocky and Bullwinkle, The': [3663],
#  'Adventures of Sebastian Cole, The': [2680],
#  'Adventures of Sharkboy and Lavagirl 3-D, The': [10152],
#  'Adventures of Sherlock Holmes, The': [7798],
#  'Adventures of Tarzan': [15300],
#  'Adventures of Tintin, The': [18120],
#  'Adventures of Tom Sawyer, The': [13094],
#  'Adventures of Zatoichi (Zatôichi sekisho yaburi) (Zatôichi 9)': [22282],
#  'Adventures of a Dentist': [24967],
#  'Adventures of the Wilderness Family, The': [8777],
#  "Adversary, The (L'adversaire)": [9325],
#  'Advertising and the End of the World': [24318],
#  'Advise and Consent': [8593],
#  'Aelita: The Queen of Mars (Aelita)': [14374],
#  'Aeon Flux': [10417],
#  'Aerial Gunner': [15305],
#  'Aerial, The (La antena)': [12569],
#  'Affair in Trinidad': [15647],
#  'Affair of Love, An (Liaison pornographique, Une)': [3762],
#  'Affair of the Heart, An': [20977],
#  'Affair of the Necklace, The': [4863],
#  'Affair to Remember, An': [915],
#  'Affairs of Anatol, The': [13097],
#  'Affinity': [15127],
#  'Afflicted': [23411],
#  'Afflicted, The': [20931],
#  'Affliction': [2354],
#  'Affluenza': [24084],
#  'Afghan Luke': [20838],
#  'Afghan Star': [14993],
#  'Africa Screams': [7295],
#  'Africa addio': [12996],
#  'Africa: Texas Style': [24146],
#  'Africa: The Serengeti': [4363],
#  'African Cats': [17103],
#  'African Queen, The': [952],
#  'Afro Samurai: Resurrection': [13444],
#  'Afstiros katallilo': [26686],
#  'After Alice (Eye of the Killer)': [21010],
#  'After Dark, My Sweet': [5190],
#  'After Death (Posle smerti)': [14606],
#  'After Earth': [21070],
#  'After Fall, Winter': [20053],
#  'After Five in the Jungle (Nach Fünf im Urwald)': [11405],
#  'After Hours': [7307],
#  'After Image (Seeing in the Dark)': [10717],
#  'After Innocence': [10637],
#  'After Last Season': [15015],
#  'After Life (Wandafuru raifu)': [2539],
#  'After Midnight': [10718],
#  'After Office Hours': [20880],
#  'After Porn Ends': [20402],
#  'After School Midnighters (Hôkago middonaitâzu)': [21042],
#  'After School Special (a.k.a. Barely Legal)': [10518],
#  'After Sex': [13563],
#  'After Tiller': [22204],
#  'After You (Après vous...)': [10149],
#  'After the Fox (Caccia alla volpe)': [5017],
#  'After the Life': [7183],
#  'After the Rain (Ame agaru)': [9227],
#  'After the Reconciliation (Après la réconciliation)': [17315],
#  'After the Rehearsal (Efter repetitionen)': [7564],
#  'After the Sunset': [8285],
#  'After the Thin Man': [7509],
#  'After the Wedding (Efter brylluppet)': [11573],
#  'After...': [18872],
#  'After.Life': [15078],
#  'Afterburn': [13992],
#  'Afterglow': [1673],
#  'Aftermath': [20247, 24023],
#  'Aftermath: Population Zero': [24052],
#  'Afternoon Delight': [21711],
#  'Afternoon of a Torturer, The (Dupa-amiaza unui tortionar)': [18480],
#  'Afterschool': [14371],
#  'Aftershock': [21061],
#  'Aftershock (Tangshan dadizhen)': [20092],
#  'Afterwards': [16111],
#  'Against All Flags': [23516],
#  'Against All Odds': [3119],
#  'Against One Another, Virtually Friends': [25183],
#  'Against The Sun': [26029],
#  'Against the Current': [16257],
#  'Against the Dark': [13465],
#  'Against the Ropes': [7203],
#  'Agata and the Storm (Agata e la tempesta)': [10865],
#  'Agatha': [10120],
#  "Agatha Christie's 'Ten Little Indians' (Ten Little Indians) (And Then There Were None)": [7741],
#  'Age of Consent': [9971],
#  'Age of Dinosaurs': [23303],
#  'Age of Heroes': [21087],
#  'Age of Ice': [26202],
#  "Age of Ignorance, The (a.k.a. Days of Darkness) (L'âge des ténèbres)": [14041],
#  'Age of Innocence, The': [408, 19832],
#  'Age of Stupid, The': [14662],
#  'Age of Tomorrow': [23897],
#  'Age of Uprising: The Legend of Michael Kohlhaas (Michael Kohlhaas)': [23044],
#  'Age of the Dragons': [20629],
#  "Age of the Medici, The (L'età di Cosimo de Medici)": [19480],
#  'Agenda: Grinding America Down': [22819],
#  'Agent Cody Banks': [6514],
#  'Agent Cody Banks 2: Destination London': [7233],
#  'Agent Red': [14650],
#  'Agent Vinod': [18871],
#  'Aglaya': [24566],
#  'Agnes Browne': [3037],
#  'Agnes of God': [3164],
#  'Agnosia': [16183],
#  'Agony (a.k.a. Rasputin) (Agoniya)': [16513],
#  'Agony and the Ecstasy of Phil Spector, The': [16200],
#  'Agony and the Ecstasy, The': [9839],
#  'Agora': [14902],
#  'Agronomist, The': [9518],
#  'Aguirre: The Wrath of God (Aguirre, der Zorn Gottes)': [6951],
#  'Ah of Life, The': [20413],
#  'Ah, Wilderness!': [21233],
#  'Ai Weiwei: Never Sorry': [19476],
#  'Aileen Wuornos: The Selling of a Serial Killer': [9039],
#  'Aileen: Life and Death of a Serial Killer': [7059],
#  'Aimée & Jaguar': [3761],
#  "Ain't Them Bodies Saints": [21497],
#  "Ain't in It for My Health: A Film About Levon Helm": [24841],
#  'Ainoat Oikeat': [26575],
#  'Air America': [3749],
#  'Air Bud': [1540],
#  'Air Bud: Golden Receiver': [2068],
#  'Air Crew': [24886],
#  'Air Doll (Kûki ningyô)': [15049],
#  'Air Force': [14784],
#  'Air Force One': [1555],
#  'Air Guitar Nation': [17638],
#  'Air Hawks': [13862],
#  'Air I Breathe, The': [12455],
#  'Air Raid Wardens': [24574],
#  'Air Up There, The': [410],
#  'Airbag': [14178],
#  'Airborne': [10139],
#  'Airheads': [409],
#  'Airplane II: The Sequel': [2706],
#  'Airplane!': [2705],
#  'Airport': [2435],
#  "Airport '77": [2437],
#  'Airport 1975': [2436],
#  'Airspeed': [20954],
#  'Ajami': [14943],
#  'Akeelah and the Bee': [10934],
#  'Akira': [1246],
#  "Akira Kurosawa's Dreams (Dreams)": [6171],
#  'Aks': [21214],
#  'Al Capone': [8570],
#  'Al Franken: God Spoke': [18110],
#  'Al otro lado': [10567],
#  'Al-risâlah': [23911],
#  'Alabama Moon': [20730],
#  "Alabama's Ghost": [16323],
#  'Aladdin': [582, 24075, 25190],
#  'Aladdin and the King of Thieves': [1044],
#  'Aladin': [15409],
#  'Alamo Bay': [24000],
#  'Alamo, The': [3948, 7267],
#  'Alan & Naomi': [11951],
#  'Alan Partridge: Alpha Papa': [21428],
#  'Alan Smithee Film: Burn Hollywood Burn, An': [1770],
#  'Alarmist, The (a.k.a. Life During Wartime)': [2232],
#  'Alaska': [795],
#  'Alaska: Silence & Solitude': [18043],
#  'Alaska: Spirit of the Wild': [4364],
#  'Alatriste': [12546],
#  'Albatross': [18429],
#  'Albert Nobbs': [18352],
#  'Albino Alligator': [1322],
#  'Albino Farm': [20875],
#  'Albuquerque': [13361],
#  'Alcan Highway (Alaska Highway)': [21423],
#  'Alcina': [19138],
#  'Alex Cross': [19739],
#  'Alex and Emma': [6383],
#  'Alex in Wonderland': [20839],
#  'Alexander': [8294],
#  'Alexander Nevsky (Aleksandr Nevskiy)': [7454],
#  'Alexander and the Terrible, Horrible, No Good, Very Bad Day': [24325],
#  'Alexander the Great': [8319],
#  "Alexander's Ragtime Band": [8198],
#  'Alexandra (Aleksandra)': [12808],
#  "Alexandra's Project": [10020],
#  'Alexandria... Why? (Iskanderija... lih?)': [18492],
#  'Alfie': [4097, 8265],
#  'Algiers': [957],
#  'Ali': [4913],
#  'Ali Baba Goes to Town': [17106],
#  'Ali G Indahouse': [9351],
#  'Ali Zoua: Prince of the Streets (Ali Zaoua, prince de la rue)': [14389],
#  'Ali: Fear Eats the Soul (Angst essen Seele auf)': [6399],
#  'Alias Betty (Betty Fisher et autres histoires)': [5478],
#  'Alias the Doctor': [24575],
#  'Alibi': [16918],
#  'Alibi, The (Lies and Alibis)': [13857],
#  'Alice': [4297, 14590, 24156],
#  'Alice (Neco z Alenky)': [8961],
#  'Alice Adams': [5921],
#  "Alice Doesn't Live Here Anymore": [8155],
#  'Alice Upside Down (Alice)': [21817],
#  'Alice and Martin (Alice et Martin)': [2687],
#  'Alice in Murderland': [25295],
#  'Alice in Wonderland': [1013, 9713, 11934, 14937, 15927, 25914],
#  'Alice in the Cities (Alice in den Stadten)': [11553],
#  "Alice's Adventures in Wonderland": [21818],
#  "Alice's Restaurant": [8680],
#  'Alice, Sweet Alice (a.k.a. Communion) (a.k.a. Holy Terror)': [2767],
#  'Alien': [1188],
#  'Alien Abduction': [24347],
#  'Alien Autopsy': [12154],
#  'Alien Cargo': [22394],
#  'Alien Contamination': [6725],
#  'Alien Escape': [1634],
#  'Alien Hunter': [9415],
#  'Alien Nation': [3610],
#  'Alien Nation: Body and Soul': [24829],
#  'Alien Nation: Dark Horizon': [24828],
#  'Alien Nation: Millennium': [24831],
#  'Alien Nation: The Enemy Within': [24830],
#  'Alien Nation: The Udara Legacy': [24244],
#  'Alien Outpost': [26409],
#  'Alien Predator (Mutant II) (Falling, The)': [24245],
#  'Alien Raiders': [13278],
#  'Alien Space Avenger': [21942],
#  'Alien Trespass': [14060],
#  'Alien from L.A.': [6789],
#  'Alien: Resurrection': [1633],
#  'Aliens': [1175],
#  'Aliens in the Attic': [14008],
#  'Aliens of the Deep': [9701],
#  'Alien³ (a.k.a. Alien 3)': [1291],
#  'Aliisa': [19387],
#  'Alila': [7210],
#  'Alive': [3163, 9423],
#  'Alive Day Memories: Home from Iraq (Occupation Iraq)': [21244],
#  'Alive Inside': [24855],
#  'Alive and Ticking (Ein Tick anders)': [21048],
#  'Aliyah (Alyah)': [22751],
#  'All About Actresses (Le bal des actrices)': [19839],
#  'All About Anna': [26129],
#  'All About Eve': [909],
#  'All About Lily Chou-Chou (Riri Shushu no subete)': [5368],
#  'All About Lola (Ce que je sais de Lola) (Lo que sé de Lola)': [14311],
#  'All About My Mother (Todo sobre mi madre)': [2996],
#  'All About Steve': [14301],
#  'All About the Benjamins': [5074],
#  'All About the Feathers (Por Las Plumas)': [23267],
#  'All Access': [4362],
#  'All American Chump': [23223],
#  'All American Orgy (Cummings Farm)': [20848],
#  'All Blossoms Again: Pedro Costa, Director (Tout refleurit: Pedro Costa, cinéaste)': [20061],
#  'All Cheerleaders Die': [25004],
#  'All Dogs Christmas Carol, An': [21841],
#  'All Dogs Go to Heaven': [2039],
#  'All Dogs Go to Heaven 2': [624],
#  'All Fall Down': [25609],
#  'All Good Things': [16325],
#  'All I Desire': [17193],
#  'All I Want (Try Seventeen)': [6729],
#  'All I Want for Christmas': [8252],
#  'All In This Tea': [26257],
#  'All In: The Poker Movie': [21088],
#  'All Is Forgiven (Tout est pardonné)': [17242],
#  'All Is Lost': [21945],
#  'All Mine to Give': [22098],
#  'All Night Long': [5609, 18445],
#  'All Over Me': [1464],
#  'All Over the Guy': [4627],
#  'All Passion Spent': [12291],
#  'All Quiet on the Western Front': [1843, 10874],
#  'All Relative': [25531],
#  'All Superheros Must Die': [20197],
#  'All That Heaven Allows': [4324],
#  'All That Jazz': [2885],
#  'All That... for This?!': [26158],
#  'All These Women (För att inte tala om alla dessa kvinnor)': [16234],
#  'All Things Fair (Lust och fägring stor)': [658],
#  'All Things to All Men': [22288],
#  'All This, and Heaven Too': [10463],
#  'All Through the Night': [8447],
#  'All Together': [26405],
#  'All Together, The': [21388],
#  "All Tomorrow's Parties": [15665],
#  'All Watched Over by Machines of Loving Grace': [18570],
#  'All at Sea': [8554],
#  'All for the Winner (Dou sing)': [23006],
#  "All in a Night's Work": [9845],
#  'All is Bright': [22201],
#  'All of Me': [7927, 23329],
#  'All or Nothing': [5689],
#  'All the Boys Love Mandy Lane': [12688],
#  'All the Brothers Were Valiant': [16739],
#  'All the Colors of the Dark': [16765],
#  'All the Fine Young Cannibals': [25449],
#  'All the Invisible Children': [11430],
#  "All the King's Men": [1858, 11347],
#  'All the Light in the Sky': [22871],
#  'All the Little Animals': [6571],
#  'All the Mornings of the World (Tous les matins du monde)': [9035],
#  "All the President's Men": [6677],
#  'All the Pretty Horses': [3937],
#  "All the Queen's Men": [5690],
#  "All the Rage (It's the Rage)": [3774],
#  'All the Real Girls': [6060],
#  'All the Right Moves': [5129],
#  'All the Vermeers in New York': [3441],
#  'All the Way Boys (Più forte, ragazzi!)': [12026],
#  'All the Way Home': [23912, 23913],
#  'All the Young Men': [22919],
#  "All's Faire in Love": [20043],
#  "All's Well": [14188],
#  'All-Star Superman': [16687],
#  'Allan Quatermain and the Lost City of Gold': [2662],
#  'Allan Quatermain and the Temple of Skulls': [12690],
#  'Allegheny Uprising': [16738],
#  'Allegro': [12304],
#  'Allegro non troppo': [7192],
#  'Alley Cats, The': [3077],
#  'Alligator': [2440],
#  'Alligator Eyes': [23930],
#  'Alligator People, The': [8207],
#  'Allnighter, The': [2159],
#  'Allotment Wives': [22548],
#  'Almanya - Welcome to Germany (Almanya - Willkommen in Deutschland)': [17628],
#  'Almighty Thor': [17553],
#  'Almost 18': [26026],
#  'Almost Famous': [3804],
#  'Almost Heroes': [1803],
#  'Almost Man, The (Mer eller mindre mann)': [22883],
#  'Almost Married': [24978],
#  'Almost You': [21825],
#  'Almost an Angel': [8977],
#  'Aloft': [26347],
#  ...}

# %%
for movies in star_rec.title_to_indices.items():
    if len(movies[1]) > 1:
        print(movies)
# Out:
# ('1', [23814, 26631])
# ('12 Angry Men', [1178, 15253])
# ('20,000 Leagues Under the Sea', [1000, 13045, 20908, 24047])
# ('3:10 to Yuma', [5203, 12089])
# ('9', [14159, 24433])
# ('Above Suspicion', [5920, 17643])
# ('Action Jackson', [3619, 25101])
# ('Adventures of Huckleberry Finn, The', [6637, 13089])
# ('Adventures of Mark Twain, The', [10206, 11851])
# ('Aftermath', [20247, 24023])
# ('Age of Innocence, The', [408, 19832])
# ('Aladdin', [582, 24075, 25190])
# ('Alamo, The', [3948, 7267])
# ('Alfie', [4097, 8265])
# ('Alice', [4297, 14590, 24156])
# ('Alice in Wonderland', [1013, 9713, 11934, 14937, 15927, 25914])
# ('Alive', [3163, 9423])
# ('All Night Long', [5609, 18445])
# ('All Quiet on the Western Front', [1843, 10874])
# ('All of Me', [7927, 23329])
# ("All the King's Men", [1858, 11347])
# ('All the Way Home', [23912, 23913])
# ('Alone in the Dark', [5819, 9699])
# ('Always', [4469, 22362])
# ('American Gun', [7225, 11042])
# ('American Virgin', [3631, 15157])
# ('Americano', [18322, 20794])
# ('Amityville Horror, The', [1298, 10035])
# ("Amour fou, L'", [14431, 16569])
# ('Anastasia', [1631, 6406])
# ('And Soon the Darkness', [12366, 16440])
# ('Andromeda Strain, The', [6204, 12713])
# ('Angel', [14242, 15097, 18273, 21801])
# ('Angels in the Outfield', [1002, 23214])
# ('Anna', [1287, 7292, 23532])
# ('Anna Karenina', [1453, 6980, 19806])
# ('Anne of Green Gables', [8902, 23294])
# ('Annie', [3945, 25355])
# ('Annie Get Your Gun', [8513, 22367, 22462])
# ("April Fool's Day", [1301, 19757])
# ('Archangel', [12767, 24374])
# ('Arena', [18700, 21415])
# ('Around the World in 80 Days', [935, 7871])
# ('Arsène Lupin', [20074, 23224])
# ('Art of the Steal, The', [16203, 22756])
# ('Arthur', [3434, 17025])
# ('As You Like It', [12331, 21003])
# ('Assault on Precinct 13', [3635, 9697])
# ('Asylum', [3666, 10311, 14515])
# ('Attack, The', [21432, 21433])
# ('Attila (Attila the Hun)', [10324, 21847])
# ('August', [652, 12833])
# ('Aurora', [18419, 26213])
# ('Avalon', [4080, 6680, 23924])
# ('Avengers, The', [2069, 17869])
# ('Aviator, The', [5235, 9588])
# ('Awakening, The', [4620, 18767])
# ('Back Street', [16661, 19039])
# ('Bad Boys', [143, 8854])
# ('Bad Company', [380, 5317, 5329])
# ('Bait', [3805, 19815])
# ('Bandits', [2477, 4748])
# ('Bangkok Dangerous', [4772, 12968])
# ('Bank, The', [6398, 18735])
# ('Barabbas', [5130, 23145, 23146])
# ('Bat, The', [2728, 24369])
# ('Batman', [586, 8646, 18191])
# ('Beautiful', [3819, 14796])
# ('Beautiful Creatures', [4148, 20503])
# ('Beauty and the Beast', [589, 23225])
# ('Bedazzled', [3874, 7429])
# ('Before and After', [111, 22722])
# ('Behind Enemy Lines', [4862, 22723])
# ('Beneath', [21414, 24409])
# ('Benji', [3581, 20540])
# ('Beowulf', [9162, 12232])
# ('Bernie', [17328, 19061])
# ('Best Man, The', [2889, 8619])
# ('Beyond a Reasonable Doubt', [11033, 14610])
# ('Big Game', [16061, 26894])
# ('Big Trouble', [4678, 6491])
# ('Black Beauty', [417, 8246])
# ('Black Christmas', [5881, 11541])
# ('Black Moon', [13073, 23644])
# ('Black Sheep', [87, 12186])
# ('Black Widow', [7193, 13406])
# ('Blackbird', [24344, 25159])
# ('Blackout', [13301, 13417, 16824, 22714])
# ('Blind Date', [3306, 5945])
# ('Blindness', [6843, 13098])
# ('Bling Ring, The', [21151, 22315])
# ('Bliss', [969, 8906])
# ('Blob, The', [1305, 4385])
# ('Blood: The Last Vampire', [9329, 14707])
# ('Blown Away', [419, 18207])
# ('Blue', [9964, 13391, 23645])
# ('Blue Bird, The', [11919, 18512])
# ('Blue Steel', [5862, 13579])
# ('Bluebeard', [3218, 20100])
# ('Bomber', [21408, 26772])
# ('Bonnie and Clyde', [1062, 22342])
# ('Book of Life, The', [7946, 24376])
# ('Book of Love', [7799, 10449])
# ('Boomerang', [120, 13219])
# ('Bordertown', [10207, 12080])
# ('Born Reckless', [12463, 23551])
# ('Born Yesterday', [3254, 6134])
# ('Born to Be Bad', [17189, 18650])
# ('Born to Be Wild', [6447, 20187])
# ('Borrowers, The', [1765, 20625])
# ('Bourne Identity, The', [5321, 8953])
# ('Box, The', [14459, 16075])
# ('Boy', [16971, 23192])
# ('Boy Meets Girl', [7438, 8883, 18363, 26563])
# ('Boys', [691, 26918])
# ('Brainstorm', [4958, 23559])
# ('Branded', [13397, 19454])
# ('Breaking Point', [21962, 23240])
# ('Breaking and Entering', [11681, 24412])
# ('Breakout', [5205, 22132])
# ('Breathing Room', [1285, 16927])
# ('Breathless', [3493, 19522])
# ('Breed, The', [11889, 22050])
# ("Brewster's Millions", [3916, 17285])
# ('Brighton Rock', [12070, 18032])
# ('Broken', [13621, 19392])
# ('Broken Arrow', [93, 11984])
# ('Broken English', [1473, 11990])
# ('Browning Version, The', [209, 10297])
# ('Buccaneer, The', [15012, 17510])
# ('Buddy', [1501, 9500])
# ('Bug', [8219, 11874])
# ('Bully', [4355, 18914])
# ('Bus Stop', [5295, 23719])
# ('Ca$h', [15211, 16640])
# ('Cake', [12280, 25907])
# ('Camille', [8416, 15080])
# ('Camp', [6458, 26696])
# ('Candy', [4186, 10967])
# ('Cape Fear', [1313, 1314])
# ('Captain America', [9041, 21026])
# ('Captain January', [11246, 24579])
# ('Cargo', [13837, 15237, 20311, 22575])
# ('Carmen', [3135, 9910, 22404])
# ('Carrie', [1315, 8522, 10004, 21881])
# ('Casanova', [10694, 26623])
# ('Cashback', [11891, 12124])
# ('Casino Royale', [5697, 11451])
# ('Cat People', [1316, 7430])
# ('Cat and the Canary, The', [7300, 9823, 21462])
# ('Cat in the Hat, The', [6839, 19251])
# ('Caught', [978, 11869, 22504])
# ('Chain Reaction', [821, 13828])
# ('Champ, The', [3339, 8371])
# ('Chaos', [5957, 11205, 13572])
# ('Charge of the Light Brigade, The', [5284, 11420])
# ('Charleston', [25304, 26748])
# ("Charlotte's Web", [2053, 11491])
# ('Charly', [5523, 7675])
# ('Cheaper by the Dozen', [7049, 7283])
# ('Chicago', [5892, 15712])
# ('Children of the Corn', [2038, 24478])
# ('Chocolat', [3920, 4608])
# ('Choke', [13285, 23016])
# ('Christmas Carol, A', [1077, 8885, 14436, 19272, 22232, 22250])
# ('Christmas in Connecticut', [10722, 24483])
# ('Cimarron', [1844, 14831])
# ('Cinderella', [1003, 13118, 23496, 23505, 26849])
# ('Circus', [3806, 24608])
# ('Clash of the Titans', [5443, 15053])
# ('Clear History', [21450, 25831])
# ('Cleopatra', [4179, 14315, 24484])
# ('Cobra', [2691, 6690])
# ('Cold Light of Day, The', [16785, 19451])
# ('Collector, The', [7002, 14001])
# ('College', [7739, 12955])
# ('Compulsion', [11211, 24500])
# ('Conan the Barbarian', [1535, 17743])
# ('Condemned, The', [11825, 24361])
# ('Congress, The', [19990, 21894])
# ('Conquest', [15815, 21752])
# ('Conspiracy', [9319, 12858])
# ('Control', [10008, 12170])
# ('Cottage, The', [13524, 20711])
# ('Crackerjack', [10103, 22147])
# ('Crash', [1443, 10062])
# ('Crawlspace', [11579, 21545, 23553])
# ('Creature', [3106, 19004])
# ('Crew, The', [3791, 22042, 24437])
# ('Crime Wave', [13637, 22148])
# ('Crime and Punishment', [14816, 24547, 24549])
# ('Crossroads', [5010, 7651, 23869])
# ('Crush', [5187, 9829])
# ('Cry, the Beloved Country', [39, 25858])
# ('Cure, The', [217, 18734])
# ('Cyrano de Bergerac', [1249, 10877])
# ('D.O.A.', [4401, 4742, 7111])
# ('Daddy Long Legs', [3045, 11428])
# ('Dangerous Liaisons', [1936, 19141, 19857, 26375])
# ("Dante's Inferno", [11368, 24618])
# ('Dark City', [1684, 17010])
# ('Dark House', [15961, 24623])
# ('Darling', [7018, 18723, 26844])
# ('David and Lisa', [8594, 14290])
# ('Dawn of the Dead', [7248, 7275])
# ('Day of the Dead', [6621, 13533])
# ('Day the Earth Stood Still, The', [1225, 13213])
# ('Daylight', [785, 18990])
# ('Dead Awake', [12540, 17744])
# ('Dead End', [8418, 9385])
# ('Dead Silence', [11734, 22245])
# ('Dead, The', [4004, 18661])
# ('Deadfall', [17584, 19910])
# ('Deadline', [16062, 24645, 24647])
# ('Deal, The', [10176, 14053, 15458])
# ('Death at a Funeral', [11965, 15134])
# ('Death of a Salesman', [8908, 16434, 20546])
# ('Debt, The', [17637, 17721])
# ('Deception', [8483, 12622, 25975])
# ('Defiance', [8846, 13295])
# ('Delirious', [5240, 12625])
# ('Deliver Us from Evil', [11390, 23684])
# ('Derailed', [10588, 14467])
# ('Detention', [14693, 19155])
# ('Detour', [3872, 23175])
# ('Dillinger', [11372, 13843])
# ('Dirty Deeds', [9340, 10376])
# ('Dolls', [7601, 7747])
# ('Don', [13791, 20751])
# ('Don Quixote', [15749, 18730])
# ("Don't Drink the Water", [11536, 19146])
# ('Dorian Gray', [14948, 22967])
# ('Double Indemnity', [3346, 20332])
# ('Double Take', [3959, 17202])
# ('Double Trouble', [8136, 13646, 24878])
# ('Double, The', [18117, 21915])
# ('Down to Earth', [4059, 26423])
# ('Dr. Jekyll and Mr. Hyde', [7096, 7867, 8338, 24882])
# ('Dracula', [2559, 6555, 8743])
# ('Dragonfly', [5031, 23203])
# ('Dune', [1937, 7517])
# ('Dunwich Horror, The', [10777, 15167])
# ('Earth', [6572, 13704])
# ('Easy Virtue', [2141, 13770])
# ('Eat', [25018, 26077])
# ('Eden', [1737, 16921, 21164, 26348])
# ('Edge of Darkness', [14821, 16810])
# ('Elevator', [20643, 20658])
# ('Emma', [823, 9135, 16781, 16881])
# ('Empire', [5802, 20945])
# ('Employee of the Month', [9706, 11364])
# ('End of the Affair, The', [3038, 3039])
# ('Endangered Species', [5975, 24890])
# ('Endless Love', [5630, 22813, 24582])
# ('Enemy of the People, An', [23415, 23430])
# ('Enforcer, The', [4849, 7083])
# ('Enigma', [5219, 5977])
# ('Equinox', [10209, 12765])
# ('Escape Artist, The', [21972, 23615])
# ('Escapist, The', [7916, 13419])
# ('Evidence', [21478, 22778])
# ('Exit', [17993, 24808])
# ('Face', [7184, 9142])
# ('Fade to Black', [8279, 13826])
# ('Fair Game', [70, 16138])
# ('Fame', [4840, 14279])
# ('Fan, The', [769, 5556])
# ('Fanny', [13146, 13526, 25310])
# ('Farewell to Arms, A', [959, 15122])
# ('Fast and the Furious, The', [4274, 13954])
# ('Father of the Bride', [917, 6832])
# ('Fatso', [4841, 13819])
# ('Faust', [1128, 4309, 18483])
# ('Fear', [654, 22579])
# ('Fever', [4051, 19991])
# ('Fever Pitch', [2876, 9942])
# ('Final Cut, The', [8256, 22588])
# ('Fire Down Below', [1572, 7220])
# ('Fire and Ice', [4945, 13352])
# ('Firm, The', [450, 19228])
# ('First Daughter', [8186, 20347])
# ('Fist of the North Star', [7993, 12898])
# ('Flash Gordon', [4845, 13609])
# ('Flawless', [3028, 12369])
# ('Flipper', [699, 8167])
# ('Flow', [16474, 26530])
# ('Flowers in the Attic', [4015, 22712])
# ('Fly, The', [2369, 2370])
# ('Focus', [4775, 26711])
# ('Fog, The', [1105, 10510])
# ('Footloose', [3700, 18012])
# ('Forbidden', [17569, 25368])
# ('Foreigner, The', [9390, 20484])
# ('Forget Me Not', [17514, 25369])
# ('Fortress', [9073, 11215])
# ('Four Feathers, The', [5512, 9796])
# ('Four Sons', [12454, 19708])
# ('Foxfire', [820, 21106])
# ('Frankenstein', [2562, 18856])
# ('Frankie and Johnny', [4189, 4190])
# ('Freaky Friday', [1930, 6483])
# ('Freedom', [18704, 24709])
# ('Freeway', [1015, 21574])
# ('Freshman, The', [6862, 8353])
# ('Friday the 13th', [1890, 13499])
# ('Fright Night', [2781, 17707])
# ('From the Earth to the Moon', [9161, 22685])
# ('Front Page, The', [6981, 7746])
# ('Frozen', [14970, 16339, 22155])
# ('Fugitive, The', [453, 12221])
# ('Fun with Dick and Jane', [6409, 10692])
# ('Fury', [8408, 24284])
# ('Gabrielle', [11299, 23091])
# ('Gambit', [10227, 21992])
# ('Game of Death', [4346, 20499])
# ('Gaslight', [889, 8428])
# ('General, The', [2340, 2936])
# ('Get Carter', [3852, 3853])
# ('Get Over It', [1119, 4074])
# ('Getaway, The', [455, 7621])
# ('Gigi', [921, 17915])
# ('Gimme Shelter', [7346, 25426])
# ('Girl Next Door, The', [7234, 7662, 12666])
# ('Girl, The', [4163, 19749, 20638])
# ('Girlhood', [6818, 26349])
# ('Gladiator', [3487, 7664])
# ('Glass House, The', [4674, 21533])
# ('Glass Menagerie, The', [4019, 8746, 20646])
# ('Gloria', [2394, 5083, 22741])
# ('Go', [2495, 11903])
# ('Go West', [3046, 10406])
# ('Godzilla', [1798, 23367])
# ('Going the Distance', [9541, 15804])
# ('Gold', [15262, 21348, 22460])
# ('Gone in 60 Seconds', [3626, 8768])
# ('Goodbye Girl, The', [3157, 20094])
# ('Goodbye, Mr. Chips', [7199, 8683])
# ('Grace', [14267, 24981])
# ("Grandma's Boy", [10750, 23059])
# ('Great Expectations', [1675, 8484, 22030])
# ('Great Gatsby, The', [7066, 20647, 20966])
# ('Greatest, The', [8023, 15542])
# ('Grey Gardens', [7730, 14456])
# ('Guardian, The', [2896, 11356])
# ("Gulliver's Travels", [2813, 16411, 23470])
# ('Gunfighter, The', [8515, 23632])
# ('Gypsy', [3513, 13204])
# ('Hairspray', [2840, 11858])
# ('Halloween', [1898, 12066])
# ('Halloween II', [1899, 14150])
# ('Hamlet', [1378, 1857, 2734, 3507, 3632, 13354, 18112, 18967])
# ('Hammer, The', [12533, 18915])
# ('Hansel & Gretel', [5584, 22129, 25585])
# ('Happiness', [2233, 24793])
# ('Happy End', [18658, 22881])
# ('Happy New Year', [17648, 25628])
# ('Hard Way, The', [6882, 8449])
# ('Hardcore', [8216, 15928])
# ('Harvest', [2462, 25546])
# ('Harvey', [3001, 22559])
# ('Haunting, The', [2465, 2633])
# ('Hawaii', [9978, 24592])
# ('Hawking', [20463, 21691])
# ('Head Over Heels', [4047, 24694])
# ('Heartbreak Kid, The', [5022, 12137])
# ('Hearts and Minds', [1389, 8771])
# ('Heat', [5, 14726])
# ('Heaven', [2523, 5534])
# ('Heaven Can Wait', [2693, 8456])
# ('Helen of Troy', [7800, 9438])
# ('Hellgate', [24203, 26955])
# ('Helter Skelter', [10806, 24127])
# ('Hercules', [1515, 23739, 26487])
# ('Hidden Agenda', [5079, 14692])
# ('Hideaway', [237, 16774])
# ('High Noon', [1255, 14123])
# ('High School', [17088, 22403])
# ('Hills Have Eyes, The', [5490, 10904])
# ('Hiroshima', [14302, 21080])
# ('Hitcher, The', [7854, 11568])
# ('Hole, The', [9288, 16035])
# ('Home', [13877, 15564, 26904])
# ('Home Movie', [10185, 14501])
# ('Home of the Brave', [11543, 25443, 25965])
# ('Honeymoon', [20001, 24025])
# ('Hope Springs', [7784, 19336])
# ('Hotel', [6459, 18829, 26857])
# ('Houdini', [13888, 25542])
# ('Hound of the Baskervilles, The', [5286, 7801, 8813, 14864])
# ('House', [2064, 14005])
# ('House of Wax', [6519, 10061])
# ('House on Haunted Hill', [2434, 2909])
# ('Housemaid, The (Hanyo)', [16630, 17230])
# ('Hunchback of Notre Dame, The', [770, 6967, 8347])
# ('Hunger', [13185, 15963])
# ('Hunted, The', [248, 6120])
# ('Hunter, The', [4655, 18660, 19533])
# ('Hunting Party, The', [12111, 23058])
# ('Hurricane, The', [3091, 11202])
# ('Hush', [1725, 15989])
# ('I Accuse', [15441, 19850, 25867])
# ('I Love Trouble', [356, 25922])
# ('I Want You', [14229, 25824])
# ('Ice Castles', [4221, 24585])
# ('Iceman', [9669, 24820])
# ('Ideal Husband, An', [2604, 21091])
# ('Illegal', [13560, 25951])
# ('Imitation of Life', [5932, 8396])
# ('Immigrant, The', [7861, 23338])
# ('Impulse', [6784, 13272])
# ('In Cold Blood', [6742, 26018])
# ('In-Laws, The', [6268, 8838])
# ('Inferno', [3496, 9745])
# ('Inherit the Wind', [3380, 21950])
# ('Innocence', [4635, 10447, 27031])
# ('Insomnia', [1805, 5291])
# ('Into the Storm', [23353, 24021])
# ('Into the West', [6074, 13093])
# ('Into the Woods', [7898, 25174])
# ('Intruder, The', [8588, 20965])
# ('Invaders from Mars', [5884, 14542])
# ('Invasion of the Body Snatchers', [2578, 6889])
# ('Invincible', [5516, 11255])
# ('Invisible Woman, The', [10124, 22496])
# ('Island of Dr. Moreau, The', [864, 15496])
# ('Island, The', [5095, 10267])
# ('It', [7141, 8989])
# ("It's Alive", [8249, 16546])
# ('Italian Job, The', [6272, 6783])
# ('Ivanhoe', [7856, 11279])
# ('Jack Frost', [2307, 9122, 25808])
# ('Jack the Giant Killer', [12028, 25632])
# ('Jane Eyre', [607, 6871, 7078, 16894, 17300])
# ('Jazz Singer, The', [5096, 8356])
# ('Jealousy', [25845, 26734])
# ('Jersey Girl', [7254, 7305])
# ('Jesus Christ Superstar', [6948, 13449])
# ('Joan of Arc', [7979, 9225])
# ('Joe', [5243, 22831])
# ('Johnny Express', [23405, 26664])
# ('Joshua', [5221, 12034])
# ('Journey to the Center of the Earth', [6140, 12830, 25946])
# ('Judas Kiss', [13975, 20232])
# ('Judex', [14554, 18318])
# ('Julia', [9863, 12574])
# ('Julius Caesar', [11709, 21161])
# ('Jungle Book, The', [358, 1994])
# ('Karate Kid, The', [2335, 15551])
# ('Keeper, The', [19090, 23773])
# ('Key, The', [10362, 23799])
# ('Kid, The', [3223, 3693])
# ('Kiki', [24588, 24589])
# ('Kill Your Darlings', [13969, 21924])
# ('Killers', [15296, 25198])
# ('Killers, The', [7578, 8621])
# ('Kind Lady', [16899, 19158])
# ('King Kong', [2281, 2282, 10644])
# ("King Solomon's Mines", [4704, 7196, 8516, 24446])
# ('King and I, The', [2474, 2480])
# ('Kismet', [16586, 19515])
# ('Kiss Before Dying, A', [5867, 9018])
# ('Kiss of Death', [256, 10648])
# ('Kiss the Bride', [9825, 20283])
# ('Kiss, The', [7230, 19306, 20707])
# ('Kon-Tiki', [19599, 20400])
# ('LOL', [12361, 19579])
# ('Ladies Man, The', [3861, 8311])
# ('Lady Killer', [11191, 25941])
# ('Lady Vanishes, The', [2124, 15987])
# ('Ladykillers, The', [5503, 7255])
# ('Lassie', [480, 11273])
# ('Last Holiday', [10753, 18350])
# ('Last House on the Left, The', [5472, 13763])
# ('Last Night', [2922, 16485])
# ('Last Run, The', [17506, 21675])
# ('Last of the Mohicans, The', [1375, 8340, 16356])
# ('Late Bloomers', [1503, 19107])
# ('Legend of Sleepy Hollow, The', [11908, 20599])
# ('Let It Snow', [4279, 25300])
# ('Letter, The', [8437, 17399, 19691])
# ('Leviathan', [4523, 20641, 24502])
# ('Lights Out', [23937, 26812])
# ('Liliom', [16832, 16839])
# ('Little Lord Fauntleroy', [944, 25605])
# ('Little Miss Marker', [9618, 9619])
# ('Little Women', [258, 4825, 6942])
# ('Loaded', [608, 20775])
# ('Lodger, The', [17737, 26834])
# ('Loft', [13289, 17252])
# ('Lola', [5664, 11617])
# ('Lolita', [1941, 2643])
# ('London', [10851, 14138])
# ('London After Midnight', [12776, 20333])
# ('Lone Ranger, The', [5047, 21222])
# ("Long Day's Journey Into Night", [7967, 25697])
# ('Longest Yard, The', [4126, 10143])
# ('Lord of the Flies', [3372, 4855])
# ('Loser', [1085, 3525])
# ('Lost Horizon', [927, 11506])
# ('Lost World, The', [4182, 12726])
# ('Love', [13242, 21327])
# ('Love Affair', [267, 6727])
# ('Love Story', [4201, 14751])
# ('Love and Honor', [11747, 24681])
# ('Lucky', [15633, 18793])
# ('Lucy', [20258, 23365])
# ('Luther', [6658, 23649])
# ('M', [1232, 16229])
# ('Macbeth', [9987, 17167, 21254])
# ('Machine, The', [1399, 23156])
# ('Mad Love', [177, 11666])
# ('Madagascar', [10136, 20360])
# ('Madame Bovary', [5739, 13921])
# ('Made for Each Other', [6403, 23251])
# ('Madhouse', [6991, 10452, 18897])
# ('Magnificent Obsession', [8536, 13919])
# ('Mail Order Bride', [6819, 18701])
# ('Man Who Knew Too Much, The', [2099, 2128])
# ('Man in the Iron Mask, The', [1727, 11962])
# ('Man of the House', [271, 9779])
# ('Man of the Year', [135, 11376])
# ('Man, The', [10421, 13373])
# ('Manchurian Candidate, The', [1239, 8098])
# ('Manhunt', [20920, 22724])
# ('Maniac', [4656, 21169, 21961, 25770])
# ('Mannequin', [4038, 16884])
# ('Margaret', [18035, 26045])
# ('Marie Antoinette', [11066, 11391])
# ('Mark of Zorro, The', [924, 12727])
# ('Master, The', [2173, 19496])
# ('Matador, The', [10662, 14096])
# ('Mayerling', [7486, 14639])
# ('Maze, The', [16095, 17810])
# ('Mechanic, The', [5593, 16820])
# ('Medea', [5808, 10455])
# ('Men with Guns', [1716, 9150])
# ('Merchant of Venice, The', [9596, 21039])
# ('Mercy', [7358, 24428])
# ('Merry Widow, The', [8399, 16840, 17664])
# ('Meteor', [2441, 14151])
# ('Metropolis', [1926, 4976])
# ('Michael', [1376, 11190, 19680])
# ('Middle of Nowhere', [20356, 20895])
# ("Midsummer Night's Dream, A", [6945, 18284])
# ('Mighty Joe Young', [2344, 2345])
# ('Mildred Pierce', [2527, 17074])
# ('Miracle on 34th Street', [274, 2313])
# ('Mirage', [397, 10985])
# ('Miranda', [9341, 17702])
# ('Miss Julie', [3029, 12031])
# ('Misérables, Les', [72, 1789, 14399, 17783, 20121, 20212, 20216, 20217, 21833])
# ('Monkey Business', [5300, 8372])
# ('Monster', [7048, 25809])
# ('Montana', [3097, 13745])
# ('Monte Carlo', [16626, 17489])
# ('Moonlight Serenade', [16413, 21630])
# ('More', [4359, 8689])
# ('Morning Glory', [12023, 16178])
# ('Moulin Rouge', [4213, 8048])
# ('Mr. & Mrs. Smith', [2121, 10151])
# ('Mr. Jones', [494, 25148])
# ('Much Ado About Nothing', [493, 21114])
# ('Mulan', [1823, 18089])
# ('Mummy, The', [2532, 2548, 2549])
# ('Murder on the Orient Express', [8196, 24897])
# ('Music Man, The', [8598, 20417])
# ('Mutiny on the Bounty', [1847, 8599])
# ('My Blue Heaven', [2164, 19026])
# ('My Man Godfrey', [930, 3009])
# ('My Sister Eileen', [9847, 14581])
# ('Mysterious Island', [5731, 14900])
# ('Naked', [497, 26611])
# ('Ned Kelly', [7260, 7287])
# ('Neighbors', [5674, 16427, 23318])
# ('Next of Kin', [4534, 8895])
# ('Night Moves', [8788, 23920])
# ('Night Train', [13389, 25453])
# ('Night and the City', [9053, 9767])
# ('Night of the Demons', [8171, 19043])
# ('Night of the Living Dead', [951, 7707])
# ('Night to Remember, A', [3317, 14450])
# ('Nightmare on Elm Street, A', [1317, 15238])
# ('Nine Lives', [10550, 25586])
# ('No Man of Her Own', [17854, 20471])
# ("No Man's Land", [4045, 4871])
# ('No Way Out', [3415, 11783])
# ("Noah's Ark", [16923, 25745])
# ("Nobody's Fool", [278, 8931])
# ('Noise', [12283, 12947])
# ('Non-Stop', [7628, 22924, 25793])
# ('Nothing Personal', [961, 17847])
# ('Nothing to Lose', [859, 6936, 24772])
# ('Notorious', [913, 13376])
# ('Nutty Professor, The', [775, 2052])
# ('Of Mice and Men', [3184, 4084])
# ('Off Beat', [21708, 25653])
# ('Offside', [11388, 15826])
# ('Old Man and the Sea, The', [1063, 17771])
# ('Oliver Twist', [7759, 10433, 25797])
# ('Omen, The', [1320, 11045])
# ('On the Beach', [3291, 13003])
# ('One Week', [13979, 16408])
# ('Open Season', [398, 11357])
# ('Order, The', [6593, 10285])
# ('Othello', [25, 15400, 21322])
# ('Other Woman, The', [17288, 23254])
# ('Our Town', [3777, 19947])
# ('Out Cold', [4804, 9632])
# ('Out of the Blue', [8053, 23261])
# ('Outrage', [13721, 26882])
# ('Oxygen', [2969, 26303])
# ('Painted Veil, The', [11509, 19578])
# ('Paleface, The', [5133, 16505])
# ('Panic', [3961, 23702])
# ('Paradise', [6012, 7641, 23873, 25659])
# ('Parent Trap, The', [994, 1975])
# ('Paris', [13498, 14104])
# ('Party Girl', [185, 16001])
# ('Party Monster', [6595, 12284])
# ('Patriot, The', [3662, 14489])
# ('Patsy, The', [8312, 15579])
# ('Penelope', [10745, 12497])
# ('Pennies from Heaven', [5678, 17592])
# ('Perils of Pauline, The', [3262, 17070])
# ('Persuasion', [27, 14882])
# ('Peter Pan', [2003, 7052, 14799])
# ('Phantom', [17531, 20604])
# ('Phantom of the Opera, The', [8355, 9589, 9623])
# ('Phantom, The', [748, 15550])
# ('Phoenix', [2115, 27015])
# ('Pink Panther, The', [6552, 10840])
# ('Pinocchio', [590, 5891, 17990])
# ('Pirates of Penzance, The', [8865, 22442])
# ('Pit and the Pendulum, The', [2696, 15074])
# ('Planet of the Apes', [2444, 4548])
# ('Playing for Keeps', [13518, 20102])
# ('Poison', [3131, 26756])
# ('Police', [16249, 18748])
# ('Poseidon Adventure, The', [1929, 18508])
# ('Posse', [7970, 14965])
# ('Possessed', [7806, 13945, 17428])
# ('Possession', [3530, 5430, 14999])
# ('Postman Always Rings Twice, The', [3439, 7440])
# ('Pride', [11736, 24020])
# ('Pride and Prejudice', [7380, 7416, 25757])
# ('Priest', [296, 17169])
# ('Prince Valiant', [1766, 7971])
# ('Prisoner of Zenda, The', [8421, 8524, 23102])
# ('Private Parts', [1438, 12997])
# ('Producers, The', [2215, 10688])
# ('Project X', [6907, 18721])
# ('Prom Night', [1903, 12629])
# ('Promised Land', [6806, 20223])
# ('Proof', [6908, 10381])
# ('Proposition, The', [1741, 10506])
# ('Psycho', [1193, 2304])
# ('Pulse', [10862, 26489])
# ('Punisher, The', [4541, 7313])
# ('Pusher', [9130, 20257])
# ('Quartet', [7227, 20132, 24952])
# ('Quest, The', [692, 21728])
# ('Quick and the Dead, The', [300, 13531])
# ('Quiet American, The', [5777, 12671])
# ('Racket, The', [10197, 17179])
# ('Rage', [18160, 23292, 24475])
# ('Rain', [2818, 5231])
# ('Rainmaker, The', [1615, 11197])
# ('Raisin in the Sun, A', [3263, 22141])
# ('Rampage', [14829, 15432])
# ('Rapid Fire', [5312, 25144])
# ('Raven, The', [2694, 8405, 18885, 22543])
# ('Raw Deal', [1130, 7198])
# ("Razor's Edge, The", [2842, 7702])
# ('Real McCoy, The', [6919, 16556])
# ('Reality', [26372, 26701])
# ('Reckless', [187, 14336])
# ('Reckoning, The', [7214, 23244, 23859])
# ('Red', [13028, 16049])
# ('Red Dawn', [3352, 19892])
# ('Red Dust', [11448, 11866])
# ('Red Heat', [4436, 25998])
# ('Redline', [11800, 20000])
# ('Regeneration', [6282, 18479])
# ('Resistance', [13090, 22524])
# ('Richard III', [40, 7226, 17775])
# ('Ring, The', [2142, 5580])
# ('River, The', [3022, 9880])
# ('Road House', [4559, 10090])
# ('Road, The', [13101, 22752])
# ('Roadie', [6254, 18396])
# ('Robin Hood', [2947, 12307, 15256])
# ('RoboCop', [2899, 22754])
# ('Rollerball', [4998, 5425])
# ('Romeo and Juliet', [3577, 15348, 21857])
# ('Rookie, The', [5170, 6702])
# ("Rosemary's Baby", [2076, 23394])
# ('Runaway', [3843, 24397])
# ('Running Scared', [2372, 5143, 10857])
# ('Rush', [7681, 21649])
# ('Sabotage', [2126, 22789])
# ('Sabrina', [6, 898])
# ('Safe', [188, 18965])
# ('Safe House', [9157, 18580])
# ('Sahara', [4905, 9941, 15136])
# ('Salvage', [14415, 19788])
# ('Samsara', [7842, 19458])
# ('Samson and Delilah', [9780, 13893, 22755])
# ('Santa Claus', [25339, 26084])
# ('Savages', [12345, 19215])
# ('Saving Face', [10144, 18832])
# ('Scarecrow, The', [16426, 20547])
# ('Scarface', [4168, 8379])
# ('Scarlet Letter, The', [189, 940, 18962])
# ('Scarlet Pimpernel, The', [8400, 8853])
# ('Screamers', [75, 25321])
# ('Sea Hawk, The', [8438, 25945])
# ('Secret Garden, The', [527, 8511])
# ('Secret Life of Walter Mitty, The', [7503, 22211])
# ('Secret, The', [11595, 22486])
# ('See No Evil', [6626, 11065])
# ('Sentinel, The', [8202, 10984])
# ('September', [4313, 23295])
# ('Shadowlands', [530, 21681])
# ('Shaft', [3638, 3653])
# ('Shaggy Dog, The', [997, 10905])
# ('Shake Hands with the Devil', [15318, 21789])
# ('Shanghai', [18240, 21762])
# ('She', [10723, 11487])
# ('Shenandoah', [6313, 23209])
# ('Sherlock Holmes', [14598, 17880])
# ('Show Boat', [7855, 8413])
# ('Shutter', [10978, 12682])
# ('Sign of Four, The', [14870, 18170])
# ('Signal, The', [12408, 23726])
# ('Signs', [5405, 26095])
# ('Simon', [5148, 10133])
# ('Ski Patrol', [22235, 24721])
# ('Skylark', [25836, 25894])
# ('Sleeping Beauty', [2012, 17808, 24306])
# ('Sleepover', [1092, 7959])
# ('Sleuth', [5024, 12143])
# ('Slipstream', [12543, 20166])
# ('Slither', [8737, 10952])
# ('Smile', [8168, 9945])
# ('Snow Queen', [25689, 25932])
# ('Somebody Up There Likes Me', [10195, 21097])
# ('Somersault', [10137, 25454])
# ('Something Wild', [4315, 11508])
# ('Southern Comfort', [5760, 9332])
# ('Speedway', [8133, 22713])
# ('Spellbound', [914, 6232])
# ('Spider', [6098, 23042])
# ('Spiral', [9296, 12739])
# ('Split Second', [5138, 14225])
# ('Stage Fright', [2103, 24307])
# ('Stagecoach', [6960, 18323])
# ('Stalingrad', [747, 24609])
# ('Star Is Born, A', [3130, 8539, 9676])
# ('Stardust', [12002, 23094])
# ('State Fair', [7828, 18547])
# ('State of Play', [13648, 22438])
# ('Stay', [10520, 25538])
# ('Steel', [1547, 22975])
# ('Stella', [6222, 16536])
# ('Stepfather, The', [4575, 14350])
# ('Stepford Wives, The', [2261, 7774])
# ('Stereo', [24215, 24466])
# ('Stevie', [6170, 20214])
# ('Strange Invaders', [8874, 24398])
# ('Stranger, The', [1400, 8487])
# ('Strapped', [17415, 17653])
# ('Straw Dogs', [6202, 17811])
# ('Streetcar Named Desire, A', [1082, 22765, 22766])
# ('Stuck', [12722, 22019])
# ('Submarine', [17279, 25701])
# ('Substitute, The', [682, 20716])
# ('Summer Holiday', [5314, 16861])
# ('Summer School', [6914, 14112])
# ('Summertime', [7386, 25346])
# ('Sunset Strip', [3773, 21499])
# ('Sunshine', [3629, 11778])
# ('Supernova', [3103, 25785])
# ('Sweeney Todd: The Demon Barber of Fleet Street', [12321, 18304, 25596])
# ('Sweet November', [4061, 10811])
# ('Switch', [7402, 23886])
# ('Sybil', [11938, 25896])
# ('Take, The', [12912, 18746])
# ('Taken', [12638, 25861])
# ('Tale of Two Cities, A', [6872, 13105])
# ('Taming of the Shrew, The', [2941, 20864])
# ('Tango', [2488, 14580])
# ('Target', [137, 8920])
# ('Tarzan', [2601, 25557])
# ('Taxi', [7921, 8229])
# ("Teacher's Pet", [7062, 8567])
# ('Teen Spirit', [26406, 26754])
# ('Teenage Mutant Ninja Turtles', [3349, 23851])
# ('Tempest, The', [16802, 19957, 21212])
# ('Ten Commandments, The', [7274, 15184])
# ('Texas Chainsaw Massacre, The', [2374, 6770])
# ('The 39 Steps', [24865, 25811])
# ('The Circle', [24462, 26916])
# ('The Count of Monte Cristo', [4968, 12429, 21425, 26384])
# ('The Diary of Anne Frank', [25751, 26049])
# ('The Four Feathers', [24656, 25704])
# ('The Hound of the Baskervilles', [25477, 25715])
# ('The Incident', [8657, 25893])
# ('Theory of Everything, The', [15835, 24757])
# ('Thief of Bagdad, The', [5875, 7190])
# ('Thin Ice', [19538, 23577])
# ('Thing, The', [2203, 18013])
# ('Thomas Crown Affair, The', [2677, 2678])
# ('Three Musketeers, The', [548, 8504, 9792, 12729, 14165, 18028, 18645])
# ('Time Machine, The', [3865, 5075])
# ('Titanic', [1661, 3316, 25146])
# ('To Be or Not to Be', [929, 8876])
# ('Tom Sawyer', [12753, 25995])
# ('Topaze', [25548, 25991])
# ('Tormented', [7133, 14387])
# ('Total Recall', [2830, 19278])
# ('Trance', [15843, 20783, 25036])
# ('Trash', [15027, 24689])
# ('Trauma', [9471, 10867])
# ('Treasure Island', [6297, 7467, 15620, 19239])
# ('Trespass', [7172, 18146])
# ('Tribute', [14129, 16131])
# ('Trick', [2635, 23321])
# ('Trick or Treat', [2379, 26085])
# ('Trip, The', [6243, 7591, 16606])
# ('True Crime', [683, 2476])
# ('True Grit', [3404, 16341])
# ('Trust', [1209, 17245])
# ('Twilight', [1718, 13174])
# ('Twisted', [1663, 7209])
# ('Twister', [724, 7474])
# ("Tyler Perry's A Madea Christmas", [25242, 26493])
# ('Tyson', [13854, 24535])
# ('Undefeated, The', [6352, 17563])
# ('Under Suspicion', [3813, 6713])
# ('Under the Skin', [5054, 23000])
# ('Underworld', [1396, 6644, 15713])
# ('Unfaithfully Yours', [8505, 11702])
# ('Unholy Three, The', [12774, 12775])
# ('Uninvited, The', [10131, 13384, 18213])
# ('United', [16149, 21313])
# ('Unknown', [11634, 16730])
# ('Unknown Soldier, The (Tuntematon sotilas)', [8548, 8921])
# ('Unmade Beds', [4114, 16377])
# ('Unstoppable', [9453, 16177])
# ('Vampires', [2243, 19241])
# ('Venom', [6046, 10383])
# ('Verdict, The', [2981, 16261])
# ('Vice', [17111, 26412])
# ('Vice Squad', [11627, 17520])
# ('Victim', [5974, 17208])
# ('Village of the Damned', [328, 2468])
# ('Visit, The', [4166, 8627])
# ('Waiting Room, The', [20291, 20477])
# ('Walking Dead, The', [332, 7703])
# ('Walking Tall', [7264, 8758])
# ('Wanted', [12747, 14256])
# ('War of the Worlds', [10224, 13269])
# ('Warlock', [4587, 12730])
# ('Waterloo Bridge', [9990, 11502])
# ("We're No Angels", [2179, 9915])
# ('Welcome to the Jungle', [22923, 23501])
# ('What Price Glory', [8010, 18297])
# ('When Ladies Meet', [16744, 17360])
# ('When a Stranger Calls', [4797, 10849])
# ('When in Rome', [14820, 25581])
# ('Where the Heart Is', [3474, 6371])
# ('Where the Red Fern Grows', [10973, 15971])
# ('Wicker Man, The', [4658, 11275])
# ('Wild Bill', [208, 19265])
# ('Willard', [6121, 20114])
# ('Wish You Were Here', [7797, 20984])
# ('Wizard of Oz, The', [902, 15572])
# ('Wolf', [378, 23092])
# ('Wolves', [4287, 26175])
# ('Woman in Black, The', [12958, 18557])
# ('Women in Love', [6148, 22829])
# ('Women, The', [910, 12957])
# ('Wonderland', [1600, 3731, 6758])
# ('Woyzeck', [10423, 17767])
# ('Wrong Man, The', [2098, 13039])
# ('Wuthering Heights', [4939, 7067, 8431, 18186, 24541])
# ('Yearling, The', [5502, 17659])
# ('Yesterday', [10744, 26627])
# ('Yours, Mine and Ours', [8679, 10615])
# ('Yu-Gi-Oh!', [8128, 22683])
# ('Zodiac', [11692, 26207])
# ('Zulu', [5800, 24528])
